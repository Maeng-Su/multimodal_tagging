# %%
# import requests
# from PIL import Image
# from transformers import BlipProcessor, BlipForConditionalGeneration

# processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
# model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base").to("cuda")

# img_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/demo.jpg'
# raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')

# # conditional image captioning
# text = "a photography of"
# inputs = processor(raw_image, text, return_tensors="pt").to("cuda")

# out = model.generate(**inputs)
# print(processor.decode(out[0], skip_special_tokens=True))

# %%
import os
import time
import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, ConcatDataset
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

# %%
# 모델 & 프로세서 로드
model_name = "Salesforce/blip-image-captioning-base"
processor = BlipProcessor.from_pretrained(model_name)
model = BlipForConditionalGeneration.from_pretrained(model_name).to("cuda")
# Out:
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("사용 중인 디바이스:", device)
# Out:
# 사용 중인 디바이스: cuda

# %%
import os
import pickle
import torch
from torch.utils.data import Dataset
from torchvision import transforms
from PIL import Image

class KTSDatasetTorch(Dataset):
    def __init__(self, data_address, mode="train", transform=None):
        self.data_address = data_address
        self.image_dir = os.path.join(self.data_address, "images")
        self.transform = transform if transform else self.default_transform()

        # pickle 파일 로드
        pickle_file = os.path.join(self.data_address, f"{mode}.pickle")
        with open(pickle_file, "rb") as fr:
            self.dataset = pickle.load(fr)

        # 이미지 경로, 텍스트, 해시태그 추출
        self.image_paths = []
        self.texts = []
        self.tags = []

        for data in self.dataset:
            if "img_name" in data and "hashtag" in data and data["hashtag"] and "text" in data:
                img_path = os.path.join(self.image_dir, data["img_name"].replace("\\", "/").split("images/")[-1])
                if os.path.exists(img_path):
                    self.image_paths.append(img_path)
                    self.texts.append(data["text"])
                    self.tags.append(data["hashtag"])  

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        text = self.texts[idx]
        tag = self.tags[idx]

        image = Image.open(img_path).convert("RGB")
        image = self.transform(image)

        return image, text, tag


    def default_transform(self):
        return transforms.Compose([
            transforms.Resize((84, 84)),
            transforms.ToTensor(),
        ])

# %%
# 데이터셋 생성
train_dataset = KTSDatasetTorch(data_address="/kaggle/input/korean-tourist-spot-dataset/Korean-Tourist-Spot-Dataset-master/kts/", mode="train", transform=None )
valid_dataset = KTSDatasetTorch(data_address="/kaggle/input/korean-tourist-spot-dataset/Korean-Tourist-Spot-Dataset-master/kts/", mode="val", transform=None )
test_dataset = KTSDatasetTorch(data_address="/kaggle/input/korean-tourist-spot-dataset/Korean-Tourist-Spot-Dataset-master/kts/", mode="test", transform=None )


# train + valid 합치기
train_valid_dataset = ConcatDataset([train_dataset, valid_dataset])

# %%
from torch.utils.data import DataLoader

#  collate_fn 정의: 이미지, 텍스트, 해시태그 리스트를 그대로 묶어줌
def custom_collate_fn(batch):
    images, texts, tags = zip(*batch)
    return list(images), list(texts), list(tags)

#  DataLoader 구성
train_valid_loader = DataLoader(
    train_valid_dataset,
    batch_size=8,
    shuffle=True,
    collate_fn=custom_collate_fn
)
test_loader = DataLoader(
    train_dataset,
    batch_size=8,
    shuffle=True,
    collate_fn=custom_collate_fn
)

# %%
sample = train_valid_dataset[-1]
print("타입:", type(sample))
print("길이:", len(sample))

for i, item in enumerate(sample):
    print(f"\n--- sample[{i}] ---")
    print("타입:", type(item))
    print(item)
# Out:
# 타입: <class 'tuple'>
# 길이: 3
#
# --- sample[0] ---
# 타입: <class 'torch.Tensor'>
# tensor([[[0.0745, 0.0745, 0.0745,  ..., 0.0627, 0.0627, 0.0627],
#          [0.0745, 0.0745, 0.0745,  ..., 0.0627, 0.0627, 0.0627],
#          [0.0745, 0.0745, 0.0745,  ..., 0.0627, 0.0627, 0.0627],
#          ...,
#          [0.4078, 0.3569, 0.3216,  ..., 0.2118, 0.2235, 0.2039],
#          [0.3647, 0.3333, 0.3059,  ..., 0.2157, 0.2784, 0.2941],
#          [0.3373, 0.3216, 0.2980,  ..., 0.2196, 0.2627, 0.2392]],
#
#         [[0.0706, 0.0706, 0.0706,  ..., 0.0627, 0.0627, 0.0627],
#          [0.0706, 0.0706, 0.0706,  ..., 0.0627, 0.0627, 0.0627],
#          [0.0745, 0.0745, 0.0745,  ..., 0.0627, 0.0627, 0.0627],
#          ...,
#          [0.4157, 0.3569, 0.3176,  ..., 0.2118, 0.2196, 0.2039],
#          [0.3725, 0.3333, 0.3020,  ..., 0.2196, 0.2745, 0.2902],
#          [0.3412, 0.3216, 0.2980,  ..., 0.2157, 0.2549, 0.2353]],
#
#         [[0.0627, 0.0627, 0.0667,  ..., 0.0588, 0.0549, 0.0549],
#          [0.0627, 0.0627, 0.0667,  ..., 0.0549, 0.0549, 0.0588],
#          [0.0667, 0.0667, 0.0667,  ..., 0.0588, 0.0549, 0.0549],
#          ...,
#          [0.3608, 0.3216, 0.3059,  ..., 0.1490, 0.1569, 0.1412],
#          [0.3255, 0.3098, 0.2941,  ..., 0.1608, 0.2078, 0.2157],
#          [0.3137, 0.3020, 0.2863,  ..., 0.1529, 0.1882, 0.1686]]])
#
# --- sample[1] ---
# 타입: <class 'str'>
# 비 오는 일요일. 하루종일 집순이 하다가 시화나래전망대 왔는데. 밤 10시까지라 못 올라감
#
# --- sample[2] ---
# 타입: <class 'list'>
# ['#행복할띵쏘', '#시화나래전망대', '#시화나래', '#시화나래휴게소', '#시화나래전망대', '#시화나래공원', '#시화나래타워', '#비오는날', '#일상', '#일상스타그램', '#소통스타그램', '#선팔하면맞팔', '#맞팔', '#소통']

# %%
from torch.optim import AdamW
optimizer = AdamW(model.parameters(), lr=5e-5, weight_decay=0.01)

def train_step(batch):
    model.train()
    images, texts, tags = batch

    # processor로 이미지 + 텍스트 인코딩
    inputs = processor(
        images=images,
        text=texts,
        return_tensors="pt",
        padding="max_length",
        truncation=True,
        max_length=35,
        do_rescale=False
    ).to(device)

    # 정답 해시태그들을 문자열로 변환
    tags_text = [" ".join(tag_list) for tag_list in tags]
    tokenized = processor.tokenizer(
        tags_text,
        return_tensors="pt",
        padding="max_length",
        truncation=True,
        max_length=35
    )
    labels = tokenized.input_ids.to(device)
    labels[labels == processor.tokenizer.pad_token_id] = -100

    # 모델 학습
    outputs = model(
        input_ids=inputs["input_ids"], 
        attention_mask=inputs["attention_mask"],
        pixel_values=inputs["pixel_values"],
        labels=labels
    )

    loss = outputs.loss
    loss.backward()

    optimizer.step()
    optimizer.zero_grad()

    return loss.item()

# %%
import torch

# 저장 경로
model_save_path = "/kaggle/working/best_model_epoch100.pth"

# 학습 파라미터 설정
num_epochs = 100
log_interval = 100
patience_limit = 2
best_loss = float('inf')
patience_counter = 0

for epoch in range(num_epochs):
    total_loss = 0
    model.train()

    for step, batch in enumerate(train_valid_loader):
        loss = train_step(batch)
        total_loss += loss

        if (step + 1) % log_interval == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{step+1}], Loss: {loss:.4f}")

    avg_loss = total_loss / len(train_valid_loader)
    print(f"Epoch {epoch+1} 완료! 평균 손실: {avg_loss:.4f}")

    # Early Stopping 로직
    if avg_loss < best_loss:
        best_loss = avg_loss
        patience_counter = 0
        print(f"손실 개선! best_loss 갱신: {best_loss:.4f}")
        
        # 모델 저장
        torch.save(model.state_dict(), model_save_path)
        print(f"모델 저장됨: {model_save_path}")
    else:
        patience_counter += 1
        print(f"손실 개선 없음. patience: {patience_counter}/{patience_limit}")
        if patience_counter >= patience_limit:
            print("Early stopping triggered!")
            break
# Out:
# Epoch [1/100], Step [100], Loss: 3.5089
# Epoch [1/100], Step [200], Loss: 3.3449
# Epoch [1/100], Step [300], Loss: 3.5218
# Epoch [1/100], Step [400], Loss: 3.1459
# Epoch [1/100], Step [500], Loss: 3.0169
# Epoch [1/100], Step [600], Loss: 3.7519
# Epoch [1/100], Step [700], Loss: 3.1518
# Epoch [1/100], Step [800], Loss: 3.7377
# Epoch [1/100], Step [900], Loss: 3.0562
# Epoch [1/100], Step [1000], Loss: 3.4165
# Epoch 1 완료! 평균 손실: 3.5777
# 손실 개선! best_loss 갱신: 3.5777
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [2/100], Step [100], Loss: 4.0858
# Epoch [2/100], Step [200], Loss: 3.7266
# Epoch [2/100], Step [300], Loss: 3.2218
# Epoch [2/100], Step [400], Loss: 3.7787
# Epoch [2/100], Step [500], Loss: 3.3418
# Epoch [2/100], Step [600], Loss: 3.1449
# Epoch [2/100], Step [700], Loss: 3.6330
# Epoch [2/100], Step [800], Loss: 3.0870
# Epoch [2/100], Step [900], Loss: 3.3549
# Epoch [2/100], Step [1000], Loss: 3.4856
# Epoch 2 완료! 평균 손실: 3.3588
# 손실 개선! best_loss 갱신: 3.3588
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [3/100], Step [100], Loss: 3.3841
# Epoch [3/100], Step [200], Loss: 3.0924
# Epoch [3/100], Step [300], Loss: 3.2333
# Epoch [3/100], Step [400], Loss: 3.3804
# Epoch [3/100], Step [500], Loss: 3.8739
# Epoch [3/100], Step [600], Loss: 2.9945
# Epoch [3/100], Step [700], Loss: 3.0807
# Epoch [3/100], Step [800], Loss: 3.4936
# Epoch [3/100], Step [900], Loss: 3.2988
# Epoch [3/100], Step [1000], Loss: 3.0433
# Epoch 3 완료! 평균 손실: 3.2902
# 손실 개선! best_loss 갱신: 3.2902
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [4/100], Step [100], Loss: 3.3884
# Epoch [4/100], Step [200], Loss: 3.4027
# Epoch [4/100], Step [300], Loss: 3.5107
# Epoch [4/100], Step [400], Loss: 2.8099
# Epoch [4/100], Step [500], Loss: 3.8904
# Epoch [4/100], Step [600], Loss: 3.0266
# Epoch [4/100], Step [700], Loss: 3.8610
# Epoch [4/100], Step [800], Loss: 3.0807
# Epoch [4/100], Step [900], Loss: 3.3114
# Epoch [4/100], Step [1000], Loss: 3.2546
# Epoch 4 완료! 평균 손실: 3.2247
# 손실 개선! best_loss 갱신: 3.2247
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [5/100], Step [100], Loss: 3.8671
# Epoch [5/100], Step [200], Loss: 2.9518
# Epoch [5/100], Step [300], Loss: 3.5961
# Epoch [5/100], Step [400], Loss: 3.2734
# Epoch [5/100], Step [500], Loss: 3.1194
# Epoch [5/100], Step [600], Loss: 3.0850
# Epoch [5/100], Step [700], Loss: 2.8535
# Epoch [5/100], Step [800], Loss: 3.1417
# Epoch [5/100], Step [900], Loss: 2.6957
# Epoch [5/100], Step [1000], Loss: 2.9450
# Epoch 5 완료! 평균 손실: 3.1540
# 손실 개선! best_loss 갱신: 3.1540
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [6/100], Step [100], Loss: 2.9028
# Epoch [6/100], Step [200], Loss: 3.3646
# Epoch [6/100], Step [300], Loss: 2.6146
# Epoch [6/100], Step [400], Loss: 3.1317
# Epoch [6/100], Step [500], Loss: 3.4566
# Epoch [6/100], Step [600], Loss: 2.9403
# Epoch [6/100], Step [700], Loss: 3.4241
# Epoch [6/100], Step [800], Loss: 2.9117
# Epoch [6/100], Step [900], Loss: 3.2253
# Epoch [6/100], Step [1000], Loss: 2.9464
# Epoch 6 완료! 평균 손실: 3.0651
# 손실 개선! best_loss 갱신: 3.0651
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [7/100], Step [100], Loss: 2.9852
# Epoch [7/100], Step [200], Loss: 2.8870
# Epoch [7/100], Step [300], Loss: 3.0172
# Epoch [7/100], Step [400], Loss: 3.4963
# Epoch [7/100], Step [500], Loss: 3.0181
# Epoch [7/100], Step [600], Loss: 3.3478
# Epoch [7/100], Step [700], Loss: 3.0490
# Epoch [7/100], Step [800], Loss: 2.6003
# Epoch [7/100], Step [900], Loss: 2.6959
# Epoch [7/100], Step [1000], Loss: 3.6003
# Epoch 7 완료! 평균 손실: 2.9534
# 손실 개선! best_loss 갱신: 2.9534
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [8/100], Step [100], Loss: 2.8320
# Epoch [8/100], Step [200], Loss: 2.8854
# Epoch [8/100], Step [300], Loss: 2.5810
# Epoch [8/100], Step [400], Loss: 2.9668
# Epoch [8/100], Step [500], Loss: 2.9400
# Epoch [8/100], Step [600], Loss: 2.5131
# Epoch [8/100], Step [700], Loss: 2.9176
# Epoch [8/100], Step [800], Loss: 3.0980
# Epoch [8/100], Step [900], Loss: 2.9865
# Epoch [8/100], Step [1000], Loss: 2.5253
# Epoch 8 완료! 평균 손실: 2.8003
# 손실 개선! best_loss 갱신: 2.8003
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [9/100], Step [100], Loss: 2.5347
# Epoch [9/100], Step [200], Loss: 2.1520
# Epoch [9/100], Step [300], Loss: 2.4855
# Epoch [9/100], Step [400], Loss: 2.6536
# Epoch [9/100], Step [500], Loss: 2.6741
# Epoch [9/100], Step [600], Loss: 2.8907
# Epoch [9/100], Step [700], Loss: 2.7434
# Epoch [9/100], Step [800], Loss: 2.5842
# Epoch [9/100], Step [900], Loss: 2.7299
# Epoch [9/100], Step [1000], Loss: 3.0027
# Epoch 9 완료! 평균 손실: 2.5931
# 손실 개선! best_loss 갱신: 2.5931
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [10/100], Step [100], Loss: 2.2883
# Epoch [10/100], Step [200], Loss: 1.9776
# Epoch [10/100], Step [300], Loss: 2.1140
# Epoch [10/100], Step [400], Loss: 2.2790
# Epoch [10/100], Step [500], Loss: 2.3758
# Epoch [10/100], Step [600], Loss: 2.5960
# Epoch [10/100], Step [700], Loss: 2.5006
# Epoch [10/100], Step [800], Loss: 2.0211
# Epoch [10/100], Step [900], Loss: 2.6369
# Epoch [10/100], Step [1000], Loss: 2.1483
# Epoch 10 완료! 평균 손실: 2.3540
# 손실 개선! best_loss 갱신: 2.3540
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [11/100], Step [100], Loss: 2.2607
# Epoch [11/100], Step [200], Loss: 2.2062
# Epoch [11/100], Step [300], Loss: 2.0169
# Epoch [11/100], Step [400], Loss: 1.9112
# Epoch [11/100], Step [500], Loss: 2.2392
# Epoch [11/100], Step [600], Loss: 1.8684
# Epoch [11/100], Step [700], Loss: 2.2156
# Epoch [11/100], Step [800], Loss: 1.9618
# Epoch [11/100], Step [900], Loss: 1.9102
# Epoch [11/100], Step [1000], Loss: 2.0180
# Epoch 11 완료! 평균 손실: 2.0617
# 손실 개선! best_loss 갱신: 2.0617
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [12/100], Step [100], Loss: 1.5147
# Epoch [12/100], Step [200], Loss: 1.4200
# Epoch [12/100], Step [300], Loss: 1.6382
# Epoch [12/100], Step [400], Loss: 1.6464
# Epoch [12/100], Step [500], Loss: 1.6442
# Epoch [12/100], Step [600], Loss: 1.8536
# Epoch [12/100], Step [700], Loss: 1.3540
# Epoch [12/100], Step [800], Loss: 1.8666
# Epoch [12/100], Step [900], Loss: 2.0853
# Epoch [12/100], Step [1000], Loss: 2.2301
# Epoch 12 완료! 평균 손실: 1.7307
# 손실 개선! best_loss 갱신: 1.7307
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [13/100], Step [100], Loss: 1.4831
# Epoch [13/100], Step [200], Loss: 1.5300
# Epoch [13/100], Step [300], Loss: 1.5060
# Epoch [13/100], Step [400], Loss: 1.4500
# Epoch [13/100], Step [500], Loss: 1.2615
# Epoch [13/100], Step [600], Loss: 1.5142
# Epoch [13/100], Step [700], Loss: 1.3801
# Epoch [13/100], Step [800], Loss: 1.6663
# Epoch [13/100], Step [900], Loss: 1.3811
# Epoch [13/100], Step [1000], Loss: 1.3412
# Epoch 13 완료! 평균 손실: 1.3863
# 손실 개선! best_loss 갱신: 1.3863
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [14/100], Step [100], Loss: 0.7068
# Epoch [14/100], Step [200], Loss: 0.9271
# Epoch [14/100], Step [300], Loss: 0.9031
# Epoch [14/100], Step [400], Loss: 1.2466
# Epoch [14/100], Step [500], Loss: 1.1981
# Epoch [14/100], Step [600], Loss: 1.1517
# Epoch [14/100], Step [700], Loss: 1.2542
# Epoch [14/100], Step [800], Loss: 1.6789
# Epoch [14/100], Step [900], Loss: 1.2193
# Epoch [14/100], Step [1000], Loss: 0.8199
# Epoch 14 완료! 평균 손실: 1.0691
# 손실 개선! best_loss 갱신: 1.0691
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [15/100], Step [100], Loss: 0.8355
# Epoch [15/100], Step [200], Loss: 0.8156
# Epoch [15/100], Step [300], Loss: 0.8229
# Epoch [15/100], Step [400], Loss: 0.8646
# Epoch [15/100], Step [500], Loss: 0.9323
# Epoch [15/100], Step [600], Loss: 0.7286
# Epoch [15/100], Step [700], Loss: 0.7063
# Epoch [15/100], Step [800], Loss: 0.7161
# Epoch [15/100], Step [900], Loss: 0.7847
# Epoch [15/100], Step [1000], Loss: 0.8598
# Epoch 15 완료! 평균 손실: 0.8065
# 손실 개선! best_loss 갱신: 0.8065
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [16/100], Step [100], Loss: 0.7156
# Epoch [16/100], Step [200], Loss: 0.6403
# Epoch [16/100], Step [300], Loss: 0.5160
# Epoch [16/100], Step [400], Loss: 0.6418
# Epoch [16/100], Step [500], Loss: 0.4241
# Epoch [16/100], Step [600], Loss: 0.5519
# Epoch [16/100], Step [700], Loss: 0.8366
# Epoch [16/100], Step [800], Loss: 0.7480
# Epoch [16/100], Step [900], Loss: 0.8549
# Epoch [16/100], Step [1000], Loss: 0.7909
# Epoch 16 완료! 평균 손실: 0.6228
# 손실 개선! best_loss 갱신: 0.6228
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [17/100], Step [100], Loss: 0.4864
# Epoch [17/100], Step [200], Loss: 0.3978
# Epoch [17/100], Step [300], Loss: 0.4058
# Epoch [17/100], Step [400], Loss: 0.6024
# Epoch [17/100], Step [500], Loss: 0.5338
# Epoch [17/100], Step [600], Loss: 0.6465
# Epoch [17/100], Step [700], Loss: 0.4130
# Epoch [17/100], Step [800], Loss: 0.5298
# Epoch [17/100], Step [900], Loss: 0.5174
# Epoch [17/100], Step [1000], Loss: 0.4612
# Epoch 17 완료! 평균 손실: 0.5000
# 손실 개선! best_loss 갱신: 0.5000
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [18/100], Step [100], Loss: 0.2698
# Epoch [18/100], Step [200], Loss: 0.3090
# Epoch [18/100], Step [300], Loss: 0.3337
# Epoch [18/100], Step [400], Loss: 0.3656
# Epoch [18/100], Step [500], Loss: 0.5121
# Epoch [18/100], Step [600], Loss: 0.2666
# Epoch [18/100], Step [700], Loss: 0.4695
# Epoch [18/100], Step [800], Loss: 0.5247
# Epoch [18/100], Step [900], Loss: 0.4406
# Epoch [18/100], Step [1000], Loss: 0.5062
# Epoch 18 완료! 평균 손실: 0.4200
# 손실 개선! best_loss 갱신: 0.4200
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [19/100], Step [100], Loss: 0.5725
# Epoch [19/100], Step [200], Loss: 0.2186
# Epoch [19/100], Step [300], Loss: 0.2756
# Epoch [19/100], Step [400], Loss: 0.2705
# Epoch [19/100], Step [500], Loss: 0.3272
# Epoch [19/100], Step [600], Loss: 0.3092
# Epoch [19/100], Step [700], Loss: 0.3350
# Epoch [19/100], Step [800], Loss: 0.2583
# Epoch [19/100], Step [900], Loss: 0.3906
# Epoch [19/100], Step [1000], Loss: 0.1579
# Epoch 19 완료! 평균 손실: 0.3602
# 손실 개선! best_loss 갱신: 0.3602
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [20/100], Step [100], Loss: 0.3923
# Epoch [20/100], Step [200], Loss: 0.1683
# Epoch [20/100], Step [300], Loss: 0.4745
# Epoch [20/100], Step [400], Loss: 0.3420
# Epoch [20/100], Step [500], Loss: 0.5071
# Epoch [20/100], Step [600], Loss: 0.3566
# Epoch [20/100], Step [700], Loss: 0.4652
# Epoch [20/100], Step [800], Loss: 0.3820
# Epoch [20/100], Step [900], Loss: 0.2290
# Epoch [20/100], Step [1000], Loss: 0.4074
# Epoch 20 완료! 평균 손실: 0.3185
# 손실 개선! best_loss 갱신: 0.3185
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [21/100], Step [100], Loss: 0.1852
# Epoch [21/100], Step [200], Loss: 0.1321
# Epoch [21/100], Step [300], Loss: 0.3733
# Epoch [21/100], Step [400], Loss: 0.4600
# Epoch [21/100], Step [500], Loss: 0.3402
# Epoch [21/100], Step [600], Loss: 0.3966
# Epoch [21/100], Step [700], Loss: 0.2869
# Epoch [21/100], Step [800], Loss: 0.2948
# Epoch [21/100], Step [900], Loss: 0.3202
# Epoch [21/100], Step [1000], Loss: 0.3531
# Epoch 21 완료! 평균 손실: 0.2838
# 손실 개선! best_loss 갱신: 0.2838
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [22/100], Step [100], Loss: 0.1826
# Epoch [22/100], Step [200], Loss: 0.2438
# Epoch [22/100], Step [300], Loss: 0.1559
# Epoch [22/100], Step [400], Loss: 0.2307
# Epoch [22/100], Step [500], Loss: 0.1672
# Epoch [22/100], Step [600], Loss: 0.2203
# Epoch [22/100], Step [700], Loss: 0.3490
# Epoch [22/100], Step [800], Loss: 0.2215
# Epoch [22/100], Step [900], Loss: 0.4858
# Epoch [22/100], Step [1000], Loss: 0.2253
# Epoch 22 완료! 평균 손실: 0.2540
# 손실 개선! best_loss 갱신: 0.2540
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [23/100], Step [100], Loss: 0.1353
# Epoch [23/100], Step [200], Loss: 0.1859
# Epoch [23/100], Step [300], Loss: 0.2229
# Epoch [23/100], Step [400], Loss: 0.1183
# Epoch [23/100], Step [500], Loss: 0.2234
# Epoch [23/100], Step [600], Loss: 0.1888
# Epoch [23/100], Step [700], Loss: 0.3847
# Epoch [23/100], Step [800], Loss: 0.2472
# Epoch [23/100], Step [900], Loss: 0.1713
# Epoch [23/100], Step [1000], Loss: 0.1615
# Epoch 23 완료! 평균 손실: 0.2182
# 손실 개선! best_loss 갱신: 0.2182
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [24/100], Step [100], Loss: 0.2680
# Epoch [24/100], Step [200], Loss: 0.0695
# Epoch [24/100], Step [300], Loss: 0.1599
# Epoch [24/100], Step [400], Loss: 0.2669
# Epoch [24/100], Step [500], Loss: 0.1616
# Epoch [24/100], Step [600], Loss: 0.1707
# Epoch [24/100], Step [700], Loss: 0.1724
# Epoch [24/100], Step [800], Loss: 0.1682
# Epoch [24/100], Step [900], Loss: 0.3099
# Epoch [24/100], Step [1000], Loss: 0.2607
# Epoch 24 완료! 평균 손실: 0.2008
# 손실 개선! best_loss 갱신: 0.2008
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [25/100], Step [100], Loss: 0.1305
# Epoch [25/100], Step [200], Loss: 0.1736
# Epoch [25/100], Step [300], Loss: 0.1974
# Epoch [25/100], Step [400], Loss: 0.2480
# Epoch [25/100], Step [500], Loss: 0.4011
# Epoch [25/100], Step [600], Loss: 0.1605
# Epoch [25/100], Step [700], Loss: 0.1853
# Epoch [25/100], Step [800], Loss: 0.2514
# Epoch [25/100], Step [900], Loss: 0.2075
# Epoch [25/100], Step [1000], Loss: 0.1482
# Epoch 25 완료! 평균 손실: 0.1814
# 손실 개선! best_loss 갱신: 0.1814
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [26/100], Step [100], Loss: 0.1179
# Epoch [26/100], Step [200], Loss: 0.0712
# Epoch [26/100], Step [300], Loss: 0.0798
# Epoch [26/100], Step [400], Loss: 0.0787
# Epoch [26/100], Step [500], Loss: 0.1407
# Epoch [26/100], Step [600], Loss: 0.1438
# Epoch [26/100], Step [700], Loss: 0.1801
# Epoch [26/100], Step [800], Loss: 0.2407
# Epoch [26/100], Step [900], Loss: 0.1859
# Epoch [26/100], Step [1000], Loss: 0.2505
# Epoch 26 완료! 평균 손실: 0.1614
# 손실 개선! best_loss 갱신: 0.1614
# 모델 저장됨: /kaggle/working/best_model_epoch100.pth
# Epoch [27/100], Step [100], Loss: 0.0978
# Epoch [27/100], Step [200], Loss: 0.0764
# Epoch [27/100], Step [300], Loss: 0.0909
# Epoch [27/100], Step [400], Loss: 0.2096
# Epoch [27/100], Step [500], Loss: 0.2086
# Epoch [27/100], Step [600], Loss: 0.1586
# Epoch [27/100], Step [700], Loss: 0.1184
# Epoch [27/100], Step [800], Loss: 0.1653
